# %%
import matplotlib.pyplot as plt

# %%
import numpy as  np

# %%
# Functional method
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.show()

# %%
"string"
# Out:
# 'string'

# %%
print("string")
# Out:
# string

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,color="g")

# %%
plt.plot(x,y)
plt.xlabel("X Lable")
plt.ylabel("Y Lable")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
# Subplot
# (number of rows ,number of columns,plot number)

# %%
plt.subplot(1,2,1)
plt.plot(x,y,".")

plt.subplot(1,2,2)
plt.plot(y,x,".")

# %%
# Object method ====>Customization is there
# In future if we want to change or anything we can perform
# Syntax=axes([left,bottom,width,height])

# %%
fig=plt.figure()
axes=fig.add_axes([0.5,0.1,0.6,0.8])

axes.plot(x,y)
axes.set_xlabel("X Lable")
axes.set_ylabel("Y Label")
axes.set_title("Function Graph")
axes.grid()

# %%
# axes.plot(x,y)
# axes.set_xlabel("X Lable")
# axes.set_ylabel("Y Label")
# # axes.set_title("Function Graph")

# %%
# axes1=fig.add_axes([0.1,0.1,0.8,0.8])
# axes2=fig.add_axes([0.2,0.5,0.4,0.3])
# axes1=plot(x,y)
# axes2=plot(y,x)

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])
axes1.plot(x,y)
axes1.set_title("Large plot")
axes2.plot(y,x)
axes2.set_title("Small plot")
axes1.grid()
axes2.grid()
